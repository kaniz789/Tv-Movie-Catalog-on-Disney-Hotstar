# %% [markdown]
# <a href="https://colab.research.google.com/github/kaniz789/Tv-Movie-Catalog-on-Disney-Hotstar/blob/main/TV_%26_Movie_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Exploratory Data Analysis using Python**

# %% [markdown]
# #**Dataset on "Disney+ Hotstar Tv and Movie Catalog"**
#
# # 1. Introduction / Objective
#
# ###In this project, we explore the Disney + Hotstar TV and Movie dataset to uncover insights about Disney+Hotstar's content production, trends over the years, and key performance indicators such as ratings, year, and genre preferences. The aim is to better understand how Disney+Hotstar’s content portfolio has evolved and identify factors that might influence a show's or movie's popularity.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.figure_factory as ff
from IPython.display import display, HTML
import plotly.express as px
import plotly.graph_objects as go
import plotly.subplots as sp
# !pip install squarify
import squarify
# Out:
# Collecting squarify
#   Downloading squarify-0.4.4-py3-none-any.whl.metadata (600 bytes)
# Downloading squarify-0.4.4-py3-none-any.whl (4.1 kB)
# Installing collected packages: squarify
# Successfully installed squarify-0.4.4

# %% [markdown]
# # 2. Dataset Overview
#
#
# *  Load and inspect the dataset. What are the columns?
#
#
# *  Check for missing values, datatypes, and basic statistics.

# %% [markdown]
# # import csv files

# %%
df = pd.read_csv("/content/hotstar.csv")
df
# Out:
#       hotstar_id                                title  \
# 0     1000087439                Sambha - Aajcha Chawa
# 1     1260023113  Cars Toon: Mater And The Ghostlight
# 2     1260103188                Kanmani Rambo Khatija
# 3     1260126754                            Butterfly
# 4     1260018228                           Sister Act
# ...          ...                                  ...
# 6869  1260127438                           Will Trent
# 6870  1260008508             KBD Juniors - Qualifiers
# 6871       12551                   Dil Hai Hindustani
# 6872  1260065225                         On The Brink
# 6873  1260129361                            Mahanadhi
#
#                                             description             genre  \
# 0     A young man sets off on a mission to clean up ...            Action
# 1     Mater is haunted by a mysterious blue light th...         Animation
# 2     Unlucky since birth, Rambo finds hope when he ...           Romance
# 3     While trying to rescue her sister's kids from ...          Thriller
# 4     Rene, a lounge singer, decides to stay at a Ch...            Comedy
# ...                                                 ...               ...
# 6869  SHOW ON BREAK- NEXT EPISODE ON 15TH FEB. Speci...             Crime
# 6870                 Match highlights of Kabaddi Junior             Sport
# 6871  Sway to the tunes of the best Hindi/Bollywood ...           Reality
# 6872  The series reveals the hidden splendours of In...  Animals & Nature
# 6873  Tragedy befalls a happy middle-class family af...            Family
#
#       year age_rating  running_time  seasons  episodes   type
# 0     2012    U/A 16+         141.0      NaN       NaN  movie
# 1     2006          U           7.0      NaN       NaN  movie
# 2     2022    U/A 16+         157.0      NaN       NaN  movie
# 3     2022    U/A 16+         136.0      NaN       NaN  movie
# 4     1992     U/A 7+         100.0      NaN       NaN  movie
# ...    ...        ...           ...      ...       ...    ...
# 6869  2023    U/A 16+           NaN      1.0       5.0     tv
# 6870  2019          U           NaN      1.0      32.0     tv
# 6871  2017    U/A 13+           NaN      2.0      57.0     tv
# 6872  2021     U/A 7+           NaN      2.0      18.0     tv
# 6873  2023    U/A 13+           NaN      1.0      10.0     tv
#
# [6874 rows x 10 columns]

# %% [markdown]
# # **check how many rows and columns in this dataset**

# %%
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of rows: 6874
# Number of columns: 10

# %% [markdown]
# # **drop columns**

# %%
df.drop(columns=['seasons', 'episodes'])
# Out:
#       hotstar_id                                title  \
# 0     1000087439                Sambha - Aajcha Chawa
# 1     1260023113  Cars Toon: Mater And The Ghostlight
# 2     1260103188                Kanmani Rambo Khatija
# 3     1260126754                            Butterfly
# 4     1260018228                           Sister Act
# ...          ...                                  ...
# 6869  1260127438                           Will Trent
# 6870  1260008508             KBD Juniors - Qualifiers
# 6871       12551                   Dil Hai Hindustani
# 6872  1260065225                         On The Brink
# 6873  1260129361                            Mahanadhi
#
#                                             description             genre  \
# 0     A young man sets off on a mission to clean up ...            Action
# 1     Mater is haunted by a mysterious blue light th...         Animation
# 2     Unlucky since birth, Rambo finds hope when he ...           Romance
# 3     While trying to rescue her sister's kids from ...          Thriller
# 4     Rene, a lounge singer, decides to stay at a Ch...            Comedy
# ...                                                 ...               ...
# 6869  SHOW ON BREAK- NEXT EPISODE ON 15TH FEB. Speci...             Crime
# 6870                 Match highlights of Kabaddi Junior             Sport
# 6871  Sway to the tunes of the best Hindi/Bollywood ...           Reality
# 6872  The series reveals the hidden splendours of In...  Animals & Nature
# 6873  Tragedy befalls a happy middle-class family af...            Family
#
#       year age_rating  running_time   type
# 0     2012    U/A 16+         141.0  movie
# 1     2006          U           7.0  movie
# 2     2022    U/A 16+         157.0  movie
# 3     2022    U/A 16+         136.0  movie
# 4     1992     U/A 7+         100.0  movie
# ...    ...        ...           ...    ...
# 6869  2023    U/A 16+           NaN     tv
# 6870  2019          U           NaN     tv
# 6871  2017    U/A 13+           NaN     tv
# 6872  2021     U/A 7+           NaN     tv
# 6873  2023    U/A 13+           NaN     tv
#
# [6874 rows x 8 columns]

# %% [markdown]
# # **column names**

# %%
list(df.columns)
# Out:
# ['hotstar_id',
#  'title',
#  'description',
#  'genre',
#  'year',
#  'age_rating',
#  'running_time',
#  'seasons',
#  'episodes',
#  'type']

# %% [markdown]
# # **check through head() if all columns are able to appear**

# %%
df.head(5)
# Out:
#    hotstar_id                                title  \
# 0  1000087439                Sambha - Aajcha Chawa
# 1  1260023113  Cars Toon: Mater And The Ghostlight
# 2  1260103188                Kanmani Rambo Khatija
# 3  1260126754                            Butterfly
# 4  1260018228                           Sister Act
#
#                                          description      genre  year  \
# 0  A young man sets off on a mission to clean up ...     Action  2012
# 1  Mater is haunted by a mysterious blue light th...  Animation  2006
# 2  Unlucky since birth, Rambo finds hope when he ...    Romance  2022
# 3  While trying to rescue her sister's kids from ...   Thriller  2022
# 4  Rene, a lounge singer, decides to stay at a Ch...     Comedy  1992
#
#   age_rating  running_time  seasons  episodes   type
# 0    U/A 16+         141.0      NaN       NaN  movie
# 1          U           7.0      NaN       NaN  movie
# 2    U/A 16+         157.0      NaN       NaN  movie
# 3    U/A 16+         136.0      NaN       NaN  movie
# 4     U/A 7+         100.0      NaN       NaN  movie

# %% [markdown]
# # **check through info()**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6874 entries, 0 to 6873
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   hotstar_id    6874 non-null   int64
#  1   title         6874 non-null   object
#  2   description   6874 non-null   object
#  3   genre         6874 non-null   object
#  4   year          6874 non-null   int64
#  5   age_rating    6874 non-null   object
#  6   running_time  4568 non-null   float64
#  7   seasons       2306 non-null   float64
#  8   episodes      2306 non-null   float64
#  9   type          6874 non-null   object
# dtypes: float64(3), int64(2), object(5)
# memory usage: 537.2+ KB

# %% [markdown]
# # **numeric columns and Categorical Columns**

# %%
numeric_cols = df.select_dtypes(include=['number']).columns
print("Numeric columns:", numeric_cols)
# Out:
# Numeric columns: Index(['hotstar_id', 'year', 'running_time', 'seasons', 'episodes'], dtype='object')

# %%
categorical_cols = df.select_dtypes(include=['object', 'category']).columns
print("Categorical columns:", categorical_cols)
# Out:
# Categorical columns: Index(['title', 'description', 'genre', 'age_rating', 'type'], dtype='object')

# %% [markdown]
# # **check through describe**

# %%
df.describe()
# Out:
#          hotstar_id         year  running_time      seasons     episodes
# count  6.874000e+03  6874.000000   4568.000000  2306.000000  2306.000000
# mean   1.059077e+09  2011.718650     98.746716     2.661752   127.366869
# std    4.812666e+08    11.936894     49.411142     4.942716   258.138186
# min    3.000000e+00  1928.000000      1.000000     1.000000     1.000000
# 25%    1.000088e+09  2009.000000     70.000000     1.000000     6.000000
# 50%    1.260008e+09  2016.000000    116.000000     1.000000    22.000000
# 75%    1.260099e+09  2019.000000    135.000000     2.000000   130.750000
# max    1.837059e+09  2023.000000    229.000000    73.000000  3973.000000

# %% [markdown]
# # **to see how many null values are there and then remove them**

# %%
df.isnull().sum()
# Out:
# hotstar_id         0
# title              0
# description        0
# genre              0
# year               0
# age_rating         0
# running_time    2306
# seasons         4568
# episodes        4568
# type               0
# dtype: int64

# %% [markdown]
# # **let's see if any duplicate**

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # **let's check how many movie and tv show are there**

# %%
df.type.value_counts()
# Out:
# type
# movie    4568
# tv       2306
# Name: count, dtype: int64

# %% [markdown]
# # **distribution of content types**

# %%
type_counts = df.type.value_counts().reset_index()
type_counts.columns = ['type', 'count']
fig = go.Figure(data=[go.Pie(labels=type_counts['type'], values=type_counts['count'])])
fig.update_layout(title_text='(Movie vs TV Show)', width = 600, height = 400)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8901de12-d638-42fe-aa66-0aed6ec00a90" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8901de12-d638-42fe-aa66-0aed6ec00a90")) {                    Plotly.newPlot(                        "8901de12-d638-42fe-aa66-0aed6ec00a90",                        [{"labels":["movie","tv"],"values":[4568,2306],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":" ...

# %% [markdown]
# # **Separating Movies and Resetting Index**

# %%
Movie=df.loc[df['type']=='movie'].reset_index(drop=True)
Movie
# Out:
#       hotstar_id                                title  \
# 0     1000087439                Sambha - Aajcha Chawa
# 1     1260023113  Cars Toon: Mater And The Ghostlight
# 2     1260103188                Kanmani Rambo Khatija
# 3     1260126754                            Butterfly
# 4     1260018228                           Sister Act
# ...          ...                                  ...
# 4563  1260061176                            Nomadland
# 4564  1808052108                       Weekend Affair
# 4565  1770021023        Muhammad Ali's Greatest Fight
# 4566  1260065445                  Playing with Sharks
# 4567  1000026118        Kunguma Poovum Konjum Puravum
#
#                                             description        genre  year  \
# 0     A young man sets off on a mission to clean up ...       Action  2012
# 1     Mater is haunted by a mysterious blue light th...    Animation  2006
# 2     Unlucky since birth, Rambo finds hope when he ...      Romance  2022
# 3     While trying to rescue her sister's kids from ...     Thriller  2022
# 4     Rene, a lounge singer, decides to stay at a Ch...       Comedy  1992
# ...                                                 ...          ...   ...
# 4563  Following the economic collapse of a town in r...        Drama  2021
# 4564  Two strangers meet at a house party. Despite b...      Romance  2020
# 4565  A story about the politics surrounding the Vie...       Biopic  2013
# 4566  "Playing with Sharks" captures the life of Val...  Documentary  2021
# 4567  Abandoned by her parents, Thulasi and her gran...        Drama  2009
#
#      age_rating  running_time  seasons  episodes   type
# 0       U/A 16+         141.0      NaN       NaN  movie
# 1             U           7.0      NaN       NaN  movie
# 2       U/A 16+         157.0      NaN       NaN  movie
# 3       U/A 16+         136.0      NaN       NaN  movie
# 4        U/A 7+         100.0      NaN       NaN  movie
# ...         ...           ...      ...       ...    ...
# 4563          A         107.0      NaN       NaN  movie
# 4564    U/A 13+           7.0      NaN       NaN  movie
# 4565    U/A 13+          93.0      NaN       NaN  movie
# 4566     U/A 7+          90.0      NaN       NaN  movie
# 4567    U/A 13+         139.0      NaN       NaN  movie
#
# [4568 rows x 10 columns]

# %% [markdown]
# # **drop seasons and episodes columns from Movie**

# %%
Movie = Movie.drop(columns=['seasons', 'episodes'])
Movie.head()
# Out:
#    hotstar_id                                title  \
# 0  1000087439                Sambha - Aajcha Chawa
# 1  1260023113  Cars Toon: Mater And The Ghostlight
# 2  1260103188                Kanmani Rambo Khatija
# 3  1260126754                            Butterfly
# 4  1260018228                           Sister Act
#
#                                          description      genre  year  \
# 0  A young man sets off on a mission to clean up ...     Action  2012
# 1  Mater is haunted by a mysterious blue light th...  Animation  2006
# 2  Unlucky since birth, Rambo finds hope when he ...    Romance  2022
# 3  While trying to rescue her sister's kids from ...   Thriller  2022
# 4  Rene, a lounge singer, decides to stay at a Ch...     Comedy  1992
#
#   age_rating  running_time   type
# 0    U/A 16+         141.0  movie
# 1          U           7.0  movie
# 2    U/A 16+         157.0  movie
# 3    U/A 16+         136.0  movie
# 4     U/A 7+         100.0  movie

# %%
# how many rows are in movie
Movie.shape[0]
# Out:
# 4568

# %% [markdown]
# # **Movie: value counts year, genre, age_rating**

# %%
#Movie['year'].value_counts()[:10]

# %%
movie_year_counts = pd.DataFrame({'Movie_Year_Valuecount': Movie['year'].value_counts().head(10)})
movie_year_counts.style.background_gradient(cmap='tab20')
# Out:
# <style type="text/css">
# #T_58c03_row0_col0, #T_58c03_row1_col0 {
#   background-color: #9edae5;
#   color: #000000;
# }
# #T_58c03_row2_col0, #T_58c03_row3_col0 {
#   background-color: #e377c2;
#   color: #f1f1f1;
# }
# #T_58c03_row4_col0 {
#   background-color: #c5b0d5;
#   color: #000000;
# }
# #T_58c03_row5_col0 {
#   background-color: #ffbb78;
#   color: #000000;
# }
# #T_58c03_row6_col0, #T_58c03_row7_col0, #T_58c03_row8_col0 {
#   background-color: #ff7f0e;
#   color: #f1f1f1;
# }
# #T_58c03_row9_col0 {
#   background-color: #1f77b4;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_58c03" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_58c03_level0_col0" class="col_heading level0 col0" >Movie_Year_Valuecount</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_58c03_level0_row0" class="row_heading level0 row0" >2022</th>
#       <td id="T_58c03_row0_col0" class="data row0 col0" >312</td>
#     </tr>
#     <tr>
#       <th id="T_58c03_level0_row1" class="row_heading level0 row1" >2021</th>
#       <td id="T_58c03_row1_col0" class="data row1 col0" >312</td>
#     </tr>
#     <tr>
#       <th id="T_58c03_level0_row2" class="row_heading level0 row2" >2017</th>
#       <td id="T_58c03_row2_col0" class="data row2 col0" >262</td>
#     </tr>
#     <tr>
#       <th id="T_58c03_level0_row3" class="row_heading level0 row3" >2019</th>
#       <td id="T_58c03_row3_col0" class="data row3 col0" >258</td>
#     </tr>
#     <tr>
#       <th id="T_58c03_level0_row4" class="row_heading level0 row4" >2018</th>
#       <td id="T_58c03_row4_col0" class="data row4 col0" >236</td>
#     </tr>
#     <tr>
#       <th id="T_58c03_level0_row5" class="row_heading level0 row5" >2020</th>
#       <td id="T_58c03_row5_col0" class="data row5 col0" >199</td>
#     </tr>
#     <tr>
#       <th id="T_58c03_level0_row6" class="row_heading level0 row6" >2016</th>
#       <td id="T_58c03_row6_col0" class="data row6 col0" >187</td>
#     </tr>
#     <tr>
#       <th id="T_58c03_level0_row7" class="row_heading level0 row7" >2015</th>
#       <td id="T_58c03_row7_col0" class="data row7 col0" >186</td>
#     </tr>
#     <tr>
#       <th id="T_58c03_level0_row8" class="row_heading level0 row8" >2010</th>
#       <td id="T_58c03_row8_col0" class="data row8 col0" >186</td>
#     </tr>
#     <tr>
#       <th id="T_58c03_level0_row9" class="row_heading level0 row9" >2011</th>
#       <td id="T_58c03_row9_col0" class="data row9 col0" >172</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Movie['genre'].value_counts()[:10]

# %%
value_count_movie = pd.DataFrame({'Movie_Genre_Valuecount': Movie['genre'].value_counts().head(10)})
value_count_movie.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_f4ab9_row0_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_f4ab9_row1_col0 {
#   background-color: #acdea6;
#   color: #000000;
# }
# #T_f4ab9_row2_col0 {
#   background-color: #b2e0ac;
#   color: #000000;
# }
# #T_f4ab9_row3_col0 {
#   background-color: #bae3b3;
#   color: #000000;
# }
# #T_f4ab9_row4_col0 {
#   background-color: #dbf1d5;
#   color: #000000;
# }
# #T_f4ab9_row5_col0 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_f4ab9_row6_col0 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_f4ab9_row7_col0 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_f4ab9_row8_col0 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_f4ab9_row9_col0 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_f4ab9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f4ab9_level0_col0" class="col_heading level0 col0" >Movie_Genre_Valuecount</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >genre</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f4ab9_level0_row0" class="row_heading level0 row0" >Drama</th>
#       <td id="T_f4ab9_row0_col0" class="data row0 col0" >1540</td>
#     </tr>
#     <tr>
#       <th id="T_f4ab9_level0_row1" class="row_heading level0 row1" >Action</th>
#       <td id="T_f4ab9_row1_col0" class="data row1 col0" >559</td>
#     </tr>
#     <tr>
#       <th id="T_f4ab9_level0_row2" class="row_heading level0 row2" >Comedy</th>
#       <td id="T_f4ab9_row2_col0" class="data row2 col0" >526</td>
#     </tr>
#     <tr>
#       <th id="T_f4ab9_level0_row3" class="row_heading level0 row3" >Romance</th>
#       <td id="T_f4ab9_row3_col0" class="data row3 col0" >494</td>
#     </tr>
#     <tr>
#       <th id="T_f4ab9_level0_row4" class="row_heading level0 row4" >Thriller</th>
#       <td id="T_f4ab9_row4_col0" class="data row4 col0" >308</td>
#     </tr>
#     <tr>
#       <th id="T_f4ab9_level0_row5" class="row_heading level0 row5" >Animation</th>
#       <td id="T_f4ab9_row5_col0" class="data row5 col0" >238</td>
#     </tr>
#     <tr>
#       <th id="T_f4ab9_level0_row6" class="row_heading level0 row6" >Family</th>
#       <td id="T_f4ab9_row6_col0" class="data row6 col0" >154</td>
#     </tr>
#     <tr>
#       <th id="T_f4ab9_level0_row7" class="row_heading level0 row7" >Documentary</th>
#       <td id="T_f4ab9_row7_col0" class="data row7 col0" >134</td>
#     </tr>
#     <tr>
#       <th id="T_f4ab9_level0_row8" class="row_heading level0 row8" >Horror</th>
#       <td id="T_f4ab9_row8_col0" class="data row8 col0" >102</td>
#     </tr>
#     <tr>
#       <th id="T_f4ab9_level0_row9" class="row_heading level0 row9" >Crime</th>
#       <td id="T_f4ab9_row9_col0" class="data row9 col0" >56</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Movie['age_rating'].value_counts()

# %%
movie_age_rating_counts = pd.DataFrame({'Movie_Age_Rating_Valuecount': Movie['age_rating'].value_counts()})
movie_age_rating_counts.style.background_gradient(cmap='Pastel1')
# Out:
# <style type="text/css">
# #T_13c93_row0_col0 {
#   background-color: #f2f2f2;
#   color: #000000;
# }
# #T_13c93_row1_col0 {
#   background-color: #fed9a6;
#   color: #000000;
# }
# #T_13c93_row2_col0 {
#   background-color: #decbe4;
#   color: #000000;
# }
# #T_13c93_row3_col0 {
#   background-color: #ccebc5;
#   color: #000000;
# }
# #T_13c93_row4_col0 {
#   background-color: #fbb4ae;
#   color: #000000;
# }
# </style>
# <table id="T_13c93" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13c93_level0_col0" class="col_heading level0 col0" >Movie_Age_Rating_Valuecount</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >age_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13c93_level0_row0" class="row_heading level0 row0" >U/A 13+</th>
#       <td id="T_13c93_row0_col0" class="data row0 col0" >1824</td>
#     </tr>
#     <tr>
#       <th id="T_13c93_level0_row1" class="row_heading level0 row1" >U/A 16+</th>
#       <td id="T_13c93_row1_col0" class="data row1 col0" >977</td>
#     </tr>
#     <tr>
#       <th id="T_13c93_level0_row2" class="row_heading level0 row2" >U</th>
#       <td id="T_13c93_row2_col0" class="data row2 col0" >868</td>
#     </tr>
#     <tr>
#       <th id="T_13c93_level0_row3" class="row_heading level0 row3" >U/A 7+</th>
#       <td id="T_13c93_row3_col0" class="data row3 col0" >721</td>
#     </tr>
#     <tr>
#       <th id="T_13c93_level0_row4" class="row_heading level0 row4" >A</th>
#       <td id="T_13c93_row4_col0" class="data row4 col0" >178</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # **Separating TV_shows and Resetting Index**

# %%
tv_shows=df.loc[df['type']=='tv'].reset_index(drop=True)
tv_shows
# Out:
#       hotstar_id                      title  \
# 0          15106                    Adorini
# 1     1260081197  Snakes SOS: Goa's Wildest
# 2           6198   Vijay Deepavali Specials
# 3     1260004278   Star Maa Parivaar League
# 4          17416              Mayavi Maling
# ...          ...                        ...
# 2301  1260127438                 Will Trent
# 2302  1260008508   KBD Juniors - Qualifiers
# 2303       12551         Dil Hai Hindustani
# 2304  1260065225               On The Brink
# 2305  1260129361                  Mahanadhi
#
#                                             description             genre  \
# 0     When Adorini, a street-dancer, gets married to...             Drama
# 1     Ben and Louise are no ordinary couple; wedding...       Documentary
# 2     Vijay TV stars come together to celebrate the ...           Reality
# 3     Packed with a high dose of entertainment, watc...           Reality
# 4     In the magical world of Maling, three princess...             Drama
# ...                                                 ...               ...
# 2301  SHOW ON BREAK- NEXT EPISODE ON 15TH FEB. Speci...             Crime
# 2302                 Match highlights of Kabaddi Junior             Sport
# 2303  Sway to the tunes of the best Hindi/Bollywood ...           Reality
# 2304  The series reveals the hidden splendours of In...  Animals & Nature
# 2305  Tragedy befalls a happy middle-class family af...            Family
#
#       year age_rating  running_time  seasons  episodes type
# 0     2017    U/A 13+           NaN      4.0     194.0   tv
# 1     2022     U/A 7+           NaN      2.0      19.0   tv
# 2     2015    U/A 13+           NaN      8.0      38.0   tv
# 3     2019    U/A 13+           NaN      3.0     115.0   tv
# 4     2018    U/A 13+           NaN      1.0      95.0   tv
# ...    ...        ...           ...      ...       ...  ...
# 2301  2023    U/A 16+           NaN      1.0       5.0   tv
# 2302  2019          U           NaN      1.0      32.0   tv
# 2303  2017    U/A 13+           NaN      2.0      57.0   tv
# 2304  2021     U/A 7+           NaN      2.0      18.0   tv
# 2305  2023    U/A 13+           NaN      1.0      10.0   tv
#
# [2306 rows x 10 columns]

# %% [markdown]
# # **drop seasons and episodes columns from TV**

# %%
tv_shows = tv_shows.drop(columns=['seasons', 'episodes'])
tv_shows.head()
# Out:
#    hotstar_id                      title  \
# 0       15106                    Adorini
# 1  1260081197  Snakes SOS: Goa's Wildest
# 2        6198   Vijay Deepavali Specials
# 3  1260004278   Star Maa Parivaar League
# 4       17416              Mayavi Maling
#
#                                          description        genre  year  \
# 0  When Adorini, a street-dancer, gets married to...        Drama  2017
# 1  Ben and Louise are no ordinary couple; wedding...  Documentary  2022
# 2  Vijay TV stars come together to celebrate the ...      Reality  2015
# 3  Packed with a high dose of entertainment, watc...      Reality  2019
# 4  In the magical world of Maling, three princess...        Drama  2018
#
#   age_rating  running_time type
# 0    U/A 13+           NaN   tv
# 1     U/A 7+           NaN   tv
# 2    U/A 13+           NaN   tv
# 3    U/A 13+           NaN   tv
# 4    U/A 13+           NaN   tv

# %%
# how many rows are in tv_shows
tv_shows.shape[0]
# Out:
# 2306

# %% [markdown]
# # **TV: value counts year, genre, age_rating**

# %%
#tv_shows['year'].value_counts()[:10]

# %%
tv_year_counts = pd.DataFrame({'TV_Show_Year_Valuecount': tv_shows['year'].value_counts().head(10)})
tv_year_counts.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_63810_row0_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_63810_row1_col0 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_63810_row2_col0 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_63810_row3_col0 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_63810_row4_col0 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_63810_row5_col0 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_63810_row6_col0 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_63810_row7_col0 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_63810_row8_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_63810_row9_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_63810" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_63810_level0_col0" class="col_heading level0 col0" >TV_Show_Year_Valuecount</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63810_level0_row0" class="row_heading level0 row0" >2022</th>
#       <td id="T_63810_row0_col0" class="data row0 col0" >297</td>
#     </tr>
#     <tr>
#       <th id="T_63810_level0_row1" class="row_heading level0 row1" >2017</th>
#       <td id="T_63810_row1_col0" class="data row1 col0" >251</td>
#     </tr>
#     <tr>
#       <th id="T_63810_level0_row2" class="row_heading level0 row2" >2021</th>
#       <td id="T_63810_row2_col0" class="data row2 col0" >249</td>
#     </tr>
#     <tr>
#       <th id="T_63810_level0_row3" class="row_heading level0 row3" >2019</th>
#       <td id="T_63810_row3_col0" class="data row3 col0" >240</td>
#     </tr>
#     <tr>
#       <th id="T_63810_level0_row4" class="row_heading level0 row4" >2016</th>
#       <td id="T_63810_row4_col0" class="data row4 col0" >236</td>
#     </tr>
#     <tr>
#       <th id="T_63810_level0_row5" class="row_heading level0 row5" >2020</th>
#       <td id="T_63810_row5_col0" class="data row5 col0" >216</td>
#     </tr>
#     <tr>
#       <th id="T_63810_level0_row6" class="row_heading level0 row6" >2018</th>
#       <td id="T_63810_row6_col0" class="data row6 col0" >213</td>
#     </tr>
#     <tr>
#       <th id="T_63810_level0_row7" class="row_heading level0 row7" >2015</th>
#       <td id="T_63810_row7_col0" class="data row7 col0" >169</td>
#     </tr>
#     <tr>
#       <th id="T_63810_level0_row8" class="row_heading level0 row8" >2023</th>
#       <td id="T_63810_row8_col0" class="data row8 col0" >128</td>
#     </tr>
#     <tr>
#       <th id="T_63810_level0_row9" class="row_heading level0 row9" >2014</th>
#       <td id="T_63810_row9_col0" class="data row9 col0" >80</td>
#     </tr>
#   </tbody>
# </table>

# %%
#tv_shows['genre'].value_counts()[:10]

# %%
value_count_tv = pd.DataFrame({'TV_Show_Genre_Valuecount': tv_shows['genre'].value_counts().head(10)})
value_count_tv.style.background_gradient(cmap='RdPu')
# Out:
# <style type="text/css">
# #T_24ecf_row0_col0 {
#   background-color: #49006a;
#   color: #f1f1f1;
# }
# #T_24ecf_row1_col0 {
#   background-color: #a6017d;
#   color: #f1f1f1;
# }
# #T_24ecf_row2_col0 {
#   background-color: #f87ca8;
#   color: #f1f1f1;
# }
# #T_24ecf_row3_col0 {
#   background-color: #fcc4c0;
#   color: #000000;
# }
# #T_24ecf_row4_col0 {
#   background-color: #fcd2ce;
#   color: #000000;
# }
# #T_24ecf_row5_col0 {
#   background-color: #fde5e2;
#   color: #000000;
# }
# #T_24ecf_row6_col0 {
#   background-color: #fff4f0;
#   color: #000000;
# }
# #T_24ecf_row7_col0 {
#   background-color: #fff5f1;
#   color: #000000;
# }
# #T_24ecf_row8_col0 {
#   background-color: #fff6f2;
#   color: #000000;
# }
# #T_24ecf_row9_col0 {
#   background-color: #fff7f3;
#   color: #000000;
# }
# </style>
# <table id="T_24ecf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_24ecf_level0_col0" class="col_heading level0 col0" >TV_Show_Genre_Valuecount</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >genre</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_24ecf_level0_row0" class="row_heading level0 row0" >Drama</th>
#       <td id="T_24ecf_row0_col0" class="data row0 col0" >503</td>
#     </tr>
#     <tr>
#       <th id="T_24ecf_level0_row1" class="row_heading level0 row1" >Reality</th>
#       <td id="T_24ecf_row1_col0" class="data row1 col0" >401</td>
#     </tr>
#     <tr>
#       <th id="T_24ecf_level0_row2" class="row_heading level0 row2" >Comedy</th>
#       <td id="T_24ecf_row2_col0" class="data row2 col0" >265</td>
#     </tr>
#     <tr>
#       <th id="T_24ecf_level0_row3" class="row_heading level0 row3" >Sport</th>
#       <td id="T_24ecf_row3_col0" class="data row3 col0" >178</td>
#     </tr>
#     <tr>
#       <th id="T_24ecf_level0_row4" class="row_heading level0 row4" >Romance</th>
#       <td id="T_24ecf_row4_col0" class="data row4 col0" >148</td>
#     </tr>
#     <tr>
#       <th id="T_24ecf_level0_row5" class="row_heading level0 row5" >Family</th>
#       <td id="T_24ecf_row5_col0" class="data row5 col0" >109</td>
#     </tr>
#     <tr>
#       <th id="T_24ecf_level0_row6" class="row_heading level0 row6" >Documentary</th>
#       <td id="T_24ecf_row6_col0" class="data row6 col0" >73</td>
#     </tr>
#     <tr>
#       <th id="T_24ecf_level0_row7" class="row_heading level0 row7" >Talk Show</th>
#       <td id="T_24ecf_row7_col0" class="data row7 col0" >72</td>
#     </tr>
#     <tr>
#       <th id="T_24ecf_level0_row8" class="row_heading level0 row8" >Animals & Nature</th>
#       <td id="T_24ecf_row8_col0" class="data row8 col0" >68</td>
#     </tr>
#     <tr>
#       <th id="T_24ecf_level0_row9" class="row_heading level0 row9" >Mythology</th>
#       <td id="T_24ecf_row9_col0" class="data row9 col0" >66</td>
#     </tr>
#   </tbody>
# </table>

# %%
#tv_shows['age_rating'].value_counts()

# %%
tv_age_rating_counts = pd.DataFrame({'TV_Show_Age_Rating_Valuecount': tv_shows['age_rating'].value_counts()})
tv_age_rating_counts.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_d73ee_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_d73ee_row1_col0 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_d73ee_row2_col0 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_d73ee_row3_col0 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_d73ee_row4_col0 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_d73ee_row5_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_d73ee" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d73ee_level0_col0" class="col_heading level0 col0" >TV_Show_Age_Rating_Valuecount</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >age_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d73ee_level0_row0" class="row_heading level0 row0" >U/A 13+</th>
#       <td id="T_d73ee_row0_col0" class="data row0 col0" >1156</td>
#     </tr>
#     <tr>
#       <th id="T_d73ee_level0_row1" class="row_heading level0 row1" >U</th>
#       <td id="T_d73ee_row1_col0" class="data row1 col0" >383</td>
#     </tr>
#     <tr>
#       <th id="T_d73ee_level0_row2" class="row_heading level0 row2" >U/A 7+</th>
#       <td id="T_d73ee_row2_col0" class="data row2 col0" >348</td>
#     </tr>
#     <tr>
#       <th id="T_d73ee_level0_row3" class="row_heading level0 row3" >U/A 16+</th>
#       <td id="T_d73ee_row3_col0" class="data row3 col0" >258</td>
#     </tr>
#     <tr>
#       <th id="T_d73ee_level0_row4" class="row_heading level0 row4" >A</th>
#       <td id="T_d73ee_row4_col0" class="data row4 col0" >160</td>
#     </tr>
#     <tr>
#       <th id="T_d73ee_level0_row5" class="row_heading level0 row5" >PG</th>
#       <td id="T_d73ee_row5_col0" class="data row5 col0" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # **Calculates the frequency of values in the 'genre' column**

# %%
data = Movie['genre'].value_counts().sort_values(ascending=False)[:10]
colors = sns.color_palette('husl', len(data))
sns.barplot(x=data.index, y=data, palette=colors)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show;
# Out:
# <ipython-input-73-193ccad4f00e>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=data.index, y=data, palette=colors)

# %%
data = tv_shows['genre'].value_counts().sort_values(ascending=False)[:10]
colors = sns.color_palette('husl', len(data))
sns.barplot(x=data.index, y=data, palette=colors)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show;
# Out:
# <ipython-input-74-0d9581ed964d>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=data.index, y=data, palette=colors)

# %% [markdown]
# # **content releases over the years**

# %%
data=Movie['year'].value_counts().sort_values(ascending=False)
sns.lineplot(x=data.index, y=data)
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %%
data=tv_shows['year'].value_counts().sort_values(ascending=False)
sns.lineplot(x=data.index, y=data)
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %% [markdown]
# # **distribution of content across different age ratings**

# %%
data = Movie['age_rating'].value_counts()
colors = sns.color_palette('husl', len(data))
sns.barplot(x=data.index, y=data, palette=colors)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-84-4d04b82aa941>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=data.index, y=data, palette=colors)

# %%
data = tv_shows['age_rating'].value_counts()
colors = sns.color_palette('husl', len(data))
sns.barplot(x=data.index, y=data, palette=colors)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-85-56a97277ae05>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=data.index, y=data, palette=colors)

# %% [markdown]
# # **Movie and TV Show Genres over the Years**

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=Movie, x='year', y='genre', label='Movie', alpha=0.6)
sns.scatterplot(data=tv_shows, x='year', y='genre', label='TV Show', alpha=0.6)
plt.title('Scatter plot of Movie and TV Show Genres over the Years')
plt.xlabel('Year')
plt.ylabel('Genre')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()
